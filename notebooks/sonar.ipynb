# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
from datasets import load_dataset

# import torch
# import sentence_transformers
from sentence_transformers import SentenceTransformer

# from sklearn.metrics.pairwise import cosine_similarity
from transformers import AutoModel, AutoTokenizer
from transformers.models.m2m_100.modeling_m2m_100 import M2M100Encoder

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# SONAR
model_name = "cointegrated/SONAR_200_text_encoder"
encoder = M2M100Encoder.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# RoBERTa (token-level embeddings)
roberta_tokenizer = AutoTokenizer.from_pretrained("xlm-roberta-base")
roberta_model = AutoModel.from_pretrained("xlm-roberta-base")

# Sentence-BERT
sbert = SentenceTransformer("sentence-transformers/paraphrase-multilingual-mpnet-base-v2")

# %% [markdown]
# # Load Datasets

# %%
# Semantic Similarity (STS Benchmark)
sts_dataset = load_dataset("glue", "stsb", split="validation")
sts_sentences = sts_dataset["sentence1"][:100], sts_dataset["sentence2"][:100]

# Cross-Lingual Retrieval (MultiEURLEX)
eurlex_dataset = load_dataset("multi_eurlex", "all_languages")
sample_en = eurlex_dataset["train"]
# Out:
# multi_eurlex.tar.gz:   0%|          | 0.00/2.77G [00:00<?, ?B/s]
# ...
# Filter:   0%|          | 0/55000 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 7
#       5 # Cross-Lingual Retrieval (MultiEURLEX)
#       6 eurlex_dataset = load_dataset('multi_eurlex', 'all_languages')  # English, German, French, Spanish
# ----> 7 sample_en = eurlex_dataset['train'].filter(lambda x: x['language'] == 'en')['text'][:50]
#       8 sample_de = eurlex_dataset['train'].filter(lambda x: x['language'] == 'de')['text'][:50]
#
# File ~/PycharmProjects/personal/lcm-explo/.venv/lib/python3.11/site-packages/datasets/arrow_dataset.py:562, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     555 self_format = {
#     556     "type": self._format_type,
#     557     "format_kwargs": self._format_kwargs,
#     558     "columns": self._format_columns,
# ...

# %%
sample_en = [x["en"] for x in eurlex_dataset["train"].map(lambda x: x["text"])["text"]]
# Out:
# Map:   0%|          | 0/55000 [00:00<?, ? examples/s]

# %%
type(eurlex_dataset)
# Out:
# datasets.dataset_dict.DatasetDict
